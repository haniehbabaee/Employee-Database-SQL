# %%
from sqlalchemy import create_engine
#from info import user_name, password 
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
engine = create_engine(f"postgres://{username}:{password}@localhost:5432/SQL_Homework")
connection = engine.connect()

# %%
#read sql file through pandas
salary_df= pd.read_sql("SELECT * FROM salaries", connection)
title_df= pd.read_sql("SELECT * FROM titles", connection)
employee_df=pd.read_sql("SELECT * FROM employees", connection)
employee_df
# Out:
#         emp_no emp_title_id  birth_date   first_name  last_name    sex  \
# 0       473302        s0001   7/25/1953     Hideyuki   Zallocco  M
# 1       475053        e0002  11/18/1954        Byong  Delgrande  F
# 2        57444        e0002   1/30/1958        Berry       Babb  F
# 3       421786        s0001   9/28/1957        Xiong   Verhoeff  M
# 4       282238        e0003  10/28/1952   Abdelkader    Baumann  F
# ...        ...          ...         ...          ...        ...    ...
# 300019  464231        s0001   8/14/1958  Constantino    Eastman  M
# 300020  255832        e0002    5/8/1955       Yuping     Dayang  F
# 300021   76671        s0001    6/9/1959       Ortrud   Plessier  M
# 300022  264920        s0001   9/22/1959        Percy   Samarati  F
# 300023  464503        s0002   5/31/1964       Arvind  Slobodova  M
#
#          hire_date
# 0        4/28/1990
# 1         9/7/1991
# 2        3/21/1992
# 3       11/26/1987
# 4        1/18/1991
# ...            ...
# ...

# %%
# Create a histogram to visualize the most common salary ranges for employees
plt.hist(salary_df["salary"], alpha=0.5)

plt.xlabel('Salary Amount')
plt.ylabel('Number of Employees')
plt.title('Most Common Salary Ranges For Employees')
plt.grid()
plt.tight_layout()
plt.show()

# %%
#Create a bar chart of average salary by title.

query = '''
SELECT t.title,s.salary
FROM "salaries" AS s
INNER JOIN "employees" AS e
ON s.emp_no=e.emp_no
INNER JOIN "titles" AS t
ON t.title_id = e.emp_title_id;
'''
#create salarybase on title dataframe
salary_title = pd.read_sql(query, connection)

# getting average of salary for each title
title_avg_salary = salary_title.groupby(["title"])["salary"].mean()

title_list = title_avg_salary.index


x_axis = np.arange(len(title_list))
plt.xticks([label for label in x_axis], title_list, rotation=45)
plt.title("Average Salary By Title")
plt.xlabel("Title")
plt.ylabel("Average Salary ($)")
chart = plt.bar(x_axis, title_avg_salary, color="r", alpha=0.5, align="center")

plt.show()
